# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('qadataset.csv')

# %%
df
# Out:
#                                              question  \
# 0    This tool is designed to create a customized ...
# 1                                                 NaN
# 2                                                 NaN
# 3   This tool is designed to create a customized m...
# 4                                                 NaN
# 5                                                 NaN
# 6   This tool is designed to create a customized m...
# 7                                                 NaN
# 8                                                 NaN
# 9   This tool is designed to create a customized m...
# 10                                                NaN
# 11                                                NaN
#
#                                               context  \
# 0    where you can build a complete machine learni...
# 1   This tool is designed to create a customized m...
# 2   This tool is designed to create a customized m...
# ...
